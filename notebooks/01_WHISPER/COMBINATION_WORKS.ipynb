# %% [markdown]
# ## Code that works

# %%
import warnings

# Suppress specific warnings by category
warnings.filterwarnings("ignore")

# speaker_diarization_transcription.py

import os
from dotenv import load_dotenv
import torch
from pyannote.audio import Pipeline
from pydub import AudioSegment
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
from collections import defaultdict

class SpeakerDiarizationTranscription:
    def __init__(self):
        # Load environment variables from .env file
        load_dotenv()

        # Access the Hugging Face token
        self.huggingface_token = os.getenv("HUGGINGFACE_TOKEN")

        # Check if the token was loaded correctly
        if self.huggingface_token:
            print("Hugging Face token loaded successfully.")
        else:
            raise ValueError("Failed to load Hugging Face token. Check your .env file.")

        # Initialize the models
        self.pipeline = self.load_pyannote_model()
        self.pipe = self.load_whisper_model()

    def load_pyannote_model(self):
        # Initialize the pyannote pipeline
        pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization@2.1", use_auth_token=self.huggingface_token)

        # Check if CUDA is available and move the pipeline to GPU if it is
        if torch.cuda.is_available():
            pipeline.to(torch.device("cuda"))
            print("Pyannote pipeline moved to GPU.")
        else:
            print("CUDA is not available. The pyannote pipeline will run on the CPU.")

        return pipeline

    def convert_to_wav(self, audio_file):
        # Check if the file is mp3 and convert to wav if necessary
        if audio_file.lower().endswith('.mp3'):
            audio = AudioSegment.from_file(audio_file)
            wav_file = audio_file.rsplit('.', 1)[0] + '.wav'
            audio.export(wav_file, format="wav")
            return wav_file
        else:
            return audio_file
    
    def perform_diarization(self, wav_file, num_speakers=None):
        # Initialize an empty list to store the diarization entries
        diarization_list = []

        # Apply the pipeline to the wav file
        diarization = self.pipeline(wav_file, num_speakers=num_speakers)

        # Iterate over the diarization results and build the list of dictionaries
        for turn, _, speaker in diarization.itertracks(yield_label=True):
            # Create a dictionary for each diarization segment
            diarization_entry = {
                'start': turn.start,
                'stop': turn.end,
                'speaker': speaker
            }
            # Add the dictionary to the list
            diarization_list.append(diarization_entry)

        return diarization_list

    def load_whisper_model(self):
        # Set device and data types
        device = "cuda" if torch.cuda.is_available() else "cpu"
        torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

        # Specify the model ID
        model_id = "openai/whisper-large-v2"  # Updated to a valid model ID

        # Load the model
        model = AutoModelForSpeechSeq2Seq.from_pretrained(
            model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True
        )
        model.to(device)

        # Load the processor
        processor = AutoProcessor.from_pretrained(model_id)

        # Create the pipeline with additional parameters
        pipe = pipeline(
            "automatic-speech-recognition",
            model=model,
            tokenizer=processor.tokenizer,
            feature_extractor=processor.feature_extractor,
            torch_dtype=torch_dtype,
            device=device,
            return_timestamps="word",  # Ensure word-level timestamps are returned
            chunk_length_s=30,         # Adjust for long audio files
            stride_length_s=(5, 5),    # Overlapping chunks to improve accuracy
        )

        print("Whisper model loaded successfully.")

        return pipe

    def transcribe_audio(self, wav_file, language):
        # Transcribe the audio file and get detailed results
        result = self.pipe(wav_file, return_timestamps=True, generate_kwargs={"language": language})

        transcription = []

        # Check if the result contains 'chunks' directly
        if 'chunks' in result:
            # Process the chunks directly
            transcription = result['chunks']
        elif 'segments' in result:
            # The 'segments' key exists, process each segment
            for segment in result['segments']:
                segment_start = segment['start']
                # Each segment may have multiple chunks
                for chunk in segment['chunks']:
                    # Adjust the chunk's timestamps to be absolute
                    t_start, t_end = chunk['timestamp']
                    chunk['timestamp'] = (t_start + segment_start, t_end + segment_start)
                    transcription.append(chunk)
        else:
            # Fallback to processing the entire result
            transcription = [{'timestamp': (result['start'], result['end']), 'text': result['text']}]

        return transcription

    def assign_speakers_to_transcription(self, diarization, transcription):
        # List to store results with assigned speakers
        assigned_transcription = []
        
        # Loop over each transcription segment to find the primary speaker
        for segment in transcription:
            segment_start, segment_end = segment['timestamp']
            segment_duration = segment_end - segment_start

            # Track overlapping time for each speaker in the current segment
            speaker_overlap = {}

            # Loop over each diarization entry to calculate overlap with the transcription segment
            for entry in diarization:
                entry_start, entry_end = entry['start'], entry['stop']
                
                # Calculate the overlap duration
                overlap_start = max(segment_start, entry_start)
                overlap_end = min(segment_end, entry_end)
                overlap_duration = max(0, overlap_end - overlap_start)

                # If there is overlap, accumulate it by speaker
                if overlap_duration > 0:
                    speaker = entry['speaker']
                    if speaker not in speaker_overlap:
                        speaker_overlap[speaker] = 0
                    speaker_overlap[speaker] += overlap_duration

            # Determine the primary speaker based on the highest overlap percentage
            if speaker_overlap:
                main_speaker = max(speaker_overlap, key=speaker_overlap.get)
                max_percentage = (speaker_overlap[main_speaker] / segment_duration) * 100
            else:
                main_speaker = None  # No clear speaker found
                max_percentage = 0

            # Append the transcription segment with identified speaker
            assigned_transcription.append({
                'timestamp': segment['timestamp'],
                'text': segment['text'],
                'main_speaker': main_speaker,
                'main_speaker_percentage': max_percentage
            })

        return assigned_transcription


    def get_diarization_and_transcription(self, audio_file, num_speakers, language):
        # Convert to wav if necessary
        wav_file = self.convert_to_wav(audio_file)

        # Perform diarization
        print("Starting speaker diarization...")
        diarization_list = self.perform_diarization(wav_file, num_speakers)
        print("Speaker diarization completed.")

        # Transcribe audio
        print("Starting transcription...")
        transcription = self.transcribe_audio(wav_file, language)
        print("Transcription completed.")

        # Clean up the temporary wav file if it was created
        if wav_file != audio_file:
            os.remove(wav_file)

        return diarization_list, transcription

    def process_audio(self, audio_file, num_speakers, language):
        # Convert to wav if necessary
        wav_file = self.convert_to_wav(audio_file)

        # Perform diarization
        print("Starting speaker diarization...")
        diarization_list = self.perform_diarization(wav_file, num_speakers)
        print("Speaker diarization completed.")

        # Transcribe audio
        print("Starting transcription...")
        transcription = self.transcribe_audio(wav_file, language)
        print("Transcription completed.")

        # Assign speakers to transcription
        print("Assigning speakers to transcription...")
        combined_result = self.assign_speakers_to_transcription(diarization_list, transcription)
        print("Speaker assignment completed.")

        # Clean up the temporary wav file if it was created
        if wav_file != audio_file:
            os.remove(wav_file)

        return combined_result

# %%
import sys
import logging
from contextlib import redirect_stdout

logging.getLogger("speechbrain").setLevel(logging.WARNING)

sdt = SpeakerDiarizationTranscription()
# Out:
# Hugging Face token loaded successfully.
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.4.0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../../../../../../../../../home/luis/.cache/torch/pyannote/models--pyannote--segmentation/snapshots/c4c8ceafcbb3a7a280c2d357aee9fbc9b0be7f9b/pytorch_model.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.3.2. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.5.1+cu124. Bad things might happen unless you revert torch to 1.x.
# Pyannote pipeline moved to GPU.
# Whisper model loaded successfully.

# %%
# Select filename
filename = "conversacion_lidix"

# Define number of speakers
num_speakers = 2

# Set lanaguage
language = "spanish"

# %%
# Path to your audio file
audio_file = f"/mnt/c/Users/luisg/Desktop/STAR/STAR/audio_samples/{filename}.mp3"  # Replace with your audio file path

# Process the audio file
combined_result = sdt.process_audio(audio_file, num_speakers, language)

# Print the results
for chunk in combined_result:
    print(f"Speaker {chunk['main_speaker']}: {chunk['text']}")
# Out:
# Starting speaker diarization...
# Speaker diarization completed.
# Starting transcription...
# You have passed language=spanish, but also have set `forced_decoder_ids` to [[1, None], [2, 50359]] which creates a conflict. `forced_decoder_ids` will be ignored in favor of language=spanish.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Transcription completed.
# Assigning speakers to transcription...
# Speaker assignment completed.
# Speaker SPEAKER_01:  Venga. Vale, se plantea la cuestión de por qué hay ciertas carreras, sobre todo las
# Speaker SPEAKER_01:  tecnológicas, las STEM, ahora han cobrado más importancia, dejando a otras en declive
# Speaker SPEAKER_01:  en estos últimos años. Vale. No lo tienes por qué hacer bien, es una conversación. Venga, cuéntamelo.
# Speaker SPEAKER_01:  Vale, bueno, hemos estructurado las carreras en cuatro grupos, o sea, tenemos cuatro grupos
# Speaker SPEAKER_01:  claramente…
# Speaker SPEAKER_00:  De estudiantes, no de carreras.
# Speaker SPEAKER_01:  Estudiantes o trabajadores. En todas las organizaciones, vamos a decir, tanto universidades como empresas,
# Speaker SPEAKER_01:  diferenciamos cuatro grupos que son los que vienen diferenciados principalmente por la motivación
# Speaker SPEAKER_01:  y por los conocimientos o competencias que tiene cada uno.
# Speaker SPEAKER_01:  Tenemos los primeros que son los que dicen o piensan, bueno, los que tienen las competencias
# Speaker SPEAKER_01:  y les gusta lo que hacen, es decir, se me da bien y me gusta.
# Speaker SPEAKER_00:  O sea, tenemos un grupo que sería el empleo perfecto, los que se te hagan bien y además les
# Speaker SPEAKER_00:  gusta estar motivados con el tema, ¿vale? Segundo grupo.
# Speaker SPEAKER_01:  Estos son los vocacionales, que son los que define Karl Newport en su libro de no sé qué,
# Speaker SPEAKER_01:  que ahora lo leeré.
# Speaker SPEAKER_01:  Esta es tu primera referencia. Sí. De Karl Newport. en su libro de no sé qué, que ahora lo leeré.
# Speaker SPEAKER_00:  Esta es tu primera referencia.
# Speaker SPEAKER_01:  Sí.
# Speaker SPEAKER_01:  De Carl Newport.
# Speaker SPEAKER_01:  Sí.
# Speaker SPEAKER_01:  Pues que los define como aquellos que están centrados en su trabajo, por lo tanto aumentan
# Speaker SPEAKER_01:  su productividad.
# Speaker SPEAKER_01:  Son los trabajadores profundos.
# Speaker SPEAKER_01:  Es que tendría que explicar un poco más lo de...
# Speaker SPEAKER_01:  Cariño, tienes cuatro minutos. Ya, pero tengo que explicar un poco más eso.
# Speaker SPEAKER_01:  Que en su estudio se focaliza en la importancia de estar conectado en un mundo con tantos
# Speaker SPEAKER_01:  estímulos y tantos cambios. Eso también lo dice ahí.
# Speaker SPEAKER_01:  Claro, porque si no estás conectado estás en el limbo. Si estás en el limbo, no haces...
# Speaker SPEAKER_01:  ¿Conectado o concentrado?
# Speaker SPEAKER_01:  Conectado es concentrado en lo que haces.
# Speaker SPEAKER_01:  En lo que haces y además te gusta.
# Speaker SPEAKER_01:  Bueno, este es el talento que les interesa a las empresas retener principalmente.
# Speaker SPEAKER_01:  Luego...
# Speaker SPEAKER_01:  Claro, las empresas tienen que trabajar en este grupo para mantener esa motivación
# Speaker SPEAKER_01:  y esos conocimientos.
# Speaker SPEAKER_01:  Luego tenemos el segundo grupo, que es donde más ha impactado el auge de la tecnología
# Speaker SPEAKER_01:  y ha hecho que en este grupo se aumente la motivación por estudiar carreras STEM,
# Speaker SPEAKER_01:  que son los que tienen las competencias adecuadas, pero a lo mejor no están tan convencidos de si les gusta o no
# Speaker SPEAKER_01:  y...
# Speaker SPEAKER_00:  o sea que no tienen tanta motivación
# Speaker SPEAKER_01:  exacto, no tienen tanta motivación porque
# Speaker SPEAKER_01:  pues porque, por las causas de desmotivación
# Speaker SPEAKER_01:  principales
# Speaker SPEAKER_01:  como pueden ser a lo mejor dificultades, no tienen tanta accesibilidad
# Speaker SPEAKER_01:  a los recursos digitales, como pueden ser las mujeres en este caso, pues cuántas mujeres
# Speaker SPEAKER_01:  hay en una clase de matemáticas?
# Speaker SPEAKER_01:  En una carrera de matemáticas, en comparación a los hombres.
# Speaker SPEAKER_00:  En matemáticas es más, es más ingenierías e informática.
# Speaker SPEAKER_01:  Pues lo menciono aquí.
# Speaker SPEAKER_01:  ¿Qué se tiene que hacer con esta gente?
# Speaker SPEAKER_01:  Es gente competente, por lo tanto nos interesa en la empresa porque nos pueden aportar.
# Speaker SPEAKER_00:  Aquí estás mezclando cosas. Una cosa es el análisis de lo que ya ha pasado, que es
# Speaker SPEAKER_00:  que han aumentado el número de stems, de interés por stems, y eso es porque en los
# Speaker SPEAKER_00:  trabajos de STEM hay mejores condiciones, porque tenemos más acceso a toda información
# Speaker SPEAKER_00:  en aprendizaje individual, que ya es independiente de los profesores, y tenemos una generación
# Speaker SPEAKER_00:  de nativos digitales y de gente que se ha acercado más a la tecnología
# Speaker SPEAKER_00:  a causa del COVID que facilita este aprendizaje con las herramientas digitales. Esto es lo que
# Speaker SPEAKER_00:  ya ha pasado. Ahora sigue habiendo más demanda de STEM que de gente que estudia STEM, de momento, ¿no? El mercado. Las empresas buscan más perfiles de STEM
# Speaker SPEAKER_00:  de los que hay disponibles. Entonces, ¿qué podemos hacer?
# Speaker SPEAKER_01:  ¿Por qué hay esta escasez de gente titulada en STEM? ¿Por qué? Si las empresas están
# Speaker SPEAKER_01:  ofreciendo las mejores condiciones en estas empresas.
# Speaker SPEAKER_00:  Porque la gente no tiene conocimiento o no elige la carrera en función a su futuro.
# Speaker SPEAKER_01:  No, porque la gente no está motivada para estudiar esto, a pesar de que les den estas condiciones.
# Speaker SPEAKER_01:  A pesar de que me vayan a pagar 50.000 euros, no me interesa estudiar tecnología.
# Speaker SPEAKER_01:  No me interesa, a pesar. No me interesa a pesar de que
# Speaker SPEAKER_01:  se me dé bien. Entonces, ¿dónde está el límite? ¿Cuál es mi estímulo principal
# Speaker SPEAKER_01:  para estudiar esto? Esto es lo que me están preguntando. ¿De dónde viene esa motivación?
# Speaker SPEAKER_01:  Pues depende, depende de cada uno. Al final hay que generalizar, es muy difícil.
# Speaker SPEAKER_00:  Pero hay que hacerlo para hacer políticas.
# Speaker SPEAKER_00:  No puedes hacer una política para cada persona.
# Speaker SPEAKER_01:  ¿Cuáles son las políticas que funcionan mejor?
# Speaker SPEAKER_00:  Pues hemos dicho dos.
# Speaker SPEAKER_00:  Hemos dicho adaptar el número de plazas universitarias
# Speaker SPEAKER_00:  a las demandas previstas futuras del mercado.
# Speaker SPEAKER_00:  Es decir, predisco que vamos a necesitar en cinco años
# Speaker SPEAKER_00:  20.000 más STEM.
# Speaker SPEAKER_00:  Pues abrimos 20.000 plazas de STEM, de diferentes carreras, de ingeniería,
# Speaker SPEAKER_00:  de informática, de matemáticas, física, lo que sea.
# Speaker SPEAKER_00:  Viceversa.
# Speaker SPEAKER_00:  Vemos que se está reduciendo la necesidad de gente que hace
# Speaker SPEAKER_00:  turismo o gente, conductores de taxi,
# Speaker SPEAKER_00:  o trabajos a lo mejor más sistemáticos de oficina,
# Speaker SPEAKER_00:  por la otra referencia esta que tenías,
# Speaker SPEAKER_00:  de que se van a reemplazar los trabajos.
# Speaker SPEAKER_01:  Inciso.
# Speaker SPEAKER_01:  Pero es que la limitación de estas plazas
# Speaker SPEAKER_01:  crea más desmotivación.
# Speaker SPEAKER_01:  Porque a lo mejor yo pienso que no soy capaz
# Speaker SPEAKER_01:  o que hay mucha mayor gente
# Speaker SPEAKER_01:  que está mejor capacitada que yo
# Speaker SPEAKER_01:  para estudiar esta carrera.
# Speaker SPEAKER_01:  Entonces yo directamente no voy a aplicar.
# Speaker SPEAKER_01:  Si sé que hay 20 plazas...
# Speaker SPEAKER_00:  Pero es que va a haber más plazas
# Speaker SPEAKER_00:  porque el mercado demanda más esto.
# Speaker SPEAKER_00:  ¿Lo entiendes? Va a haber muchas más plazas.
# Speaker SPEAKER_00:  O sea, crear empleo. No, empleo no. plazas porque el mercado demanda más esto. ¿Lo entiendes? Va a haber muchas más plazas porque hay mucha más demanda. O sea, crear empleo.
# Speaker SPEAKER_00:  No, empleo no.
# Speaker SPEAKER_00:  Plazas universitarias.
# Speaker SPEAKER_00:  El empleo ya es el que es y eso lo gestiona el mercado.
# Speaker SPEAKER_00:  Ahora tenemos que hacer que el Estado
# Speaker SPEAKER_00:  haga una forma de poner en contacto a las empresas de los universidades
# Speaker SPEAKER_00:  para satisfacer la demanda de empleo
# Speaker SPEAKER_00:  desde cuando la gente elige la carrera, la educación.
# Speaker SPEAKER_00:  ¿Entiendes?
# Speaker SPEAKER_00:  ¿Y por qué no lo hacen?
# Speaker SPEAKER_00:  Esa sería mi pregunta.
# Speaker SPEAKER_00:  Pues porque no les da la gana.
# Speaker SPEAKER_00:  Que no...
# Speaker SPEAKER_00:  Porque no les interesa, ¿eh?
# Speaker SPEAKER_00:  Porque el Estado es una mierda, lo único que quieren es ganar las siguientes elecciones.
# Speaker SPEAKER_00:  No les interesa, no, claro.
# Speaker SPEAKER_00:  Y quieren, de hecho,
# Speaker SPEAKER_00:  quieren población que haya estudiado una carrera de filosofía, que luego no les sirva para nada
# Speaker SPEAKER_00:  y esté muy indignado con el capitalismo en las empresas.
# Speaker SPEAKER_00:  Porque el Estado, pues suele ir en contra de eso, sobre todo en Europa,
# Speaker SPEAKER_00:  siendo un Estado socialista.
# Speaker SPEAKER_01:  No, porque a lo mejor no tienen suficiente financiación para...
# Speaker SPEAKER_00:  ¿Que no tienen suficiente financiación el Estado?
# Speaker SPEAKER_00:  Literalmente la mitad de lo que pagas va al Estado.
# Speaker SPEAKER_01:  No les interesa a lo mejor financiar
# Speaker SPEAKER_01:  la accesibilidad de la gente a recursos tecnológicos.
# Speaker SPEAKER_00:  No les interesa, pero bueno, se debería hacer, ¿no?
# Speaker SPEAKER_00:  Y esa sería la solución o una de las soluciones.
# Speaker SPEAKER_00:  Y luego tú antes ahí habías dicho otra.
# Speaker SPEAKER_00:  Que no me acuerdo cuál era.
# Speaker SPEAKER_01:  Una solución a la motivación.
# Speaker SPEAKER_00:  Sí. Ah, a la gente que reemplazan por máquinas.
# Speaker SPEAKER_01:  Por máquinas, exacto.
# Speaker SPEAKER_01:  Pues hay otro estudio.
# Speaker SPEAKER_01:  ¿Dilo?
# Speaker SPEAKER_01:  Sí, es el estudio de McKinsey que dice eso.
# Speaker SPEAKER_01:  Fue escrito en 2017 y decía que antes de la pandemia
# Speaker SPEAKER_01:  se estimaba ya que entre 400 y 800 millones de empleos
# Speaker SPEAKER_01:  iban a ser reemplazados por máquinas.
# Speaker SPEAKER_01:  Esto ya ha pasado. Ya hay muchísimos empleos que ya a ser reemplazados por máquinas. Esto ya ha pasado. O sea, ya
# Speaker SPEAKER_01:  hay muchísimos empleos que ya se han reemplazado.
# Speaker SPEAKER_00:  Y va a haber más. Antes eran trabajos más mecánicos, cajero y supermercado y tal.
# Speaker SPEAKER_01:  Sí, que también dicen que las tareas repetitivas son altamente susceptibles a la automatización.
# Speaker SPEAKER_00:  Pero ahora cada vez más empleos quizás no tan repetitivos se van a ir sustituyendo,
# Speaker SPEAKER_00:  como puede ser un conductor de taxi o de camión, o como puede ser trabajos incluso de oficina.
# Speaker SPEAKER_00:  Esto también crea desmotivación.
# Speaker SPEAKER_00:  Vale.
# Speaker SPEAKER_00:  Sí, pero entonces lo que decías era para esta gente a la que están sustituyendo, tanto
# Speaker SPEAKER_00:  para la gente joven como la gente mayor, ¿no?
# Speaker SPEAKER_00:  Que a lo mejor llevan toda su carrera laboral haciendo este trabajo.
# Speaker SPEAKER_01:  Pues sí, a lo mejor una solución sería...
# Speaker SPEAKER_00:  Darles opciones, ¿no?
# Speaker SPEAKER_00:  O tenemos la renta básica universal para que puedan tener acceso a estudiar otras cosas.
# Speaker SPEAKER_00:  Eso es de otro estudio, pero bueno, es una de las soluciones.
# Speaker SPEAKER_01:  No, una de las soluciones es tener en cuenta, o sea, la solución, la única solución es tener siempre en cuenta las condiciones en las que tienes a tus empleados.
# Speaker SPEAKER_01:  Porque no les va a afectar de la misma manera que a uno le cambies el sueldo o que a uno le des más ventajas que a otro. A cada uno le afecta todo de manera diferente,
# Speaker SPEAKER_01:  en eso estamos de acuerdo. Igual que les afecta diferente a estos cuatro grupos en la implementación
# Speaker SPEAKER_01:  de la tecnología. Pues que las soluciones es siempre tener en cuenta las condiciones de los empleados.
# Speaker SPEAKER_00:  ¿Pero qué empleados?
# Speaker SPEAKER_00:  Que le estamos sustituyendo a Paquita la cajera del supermercado.
# Speaker SPEAKER_01:  Paquita tiene 50 años y solo sabe
# Speaker SPEAKER_01:  pasar productos por la caja.
# Speaker SPEAKER_00:  Entonces las condiciones dan igual, porque la van a despedir y van a poner una robot a hacer eso.
# Speaker SPEAKER_00:  Claro, entonces... ¿Qué hacemos con Paquita?
# Speaker SPEAKER_01:  Hay que compensarla teniendo en cuenta qué opciones tiene Paquita.
# Speaker SPEAKER_01:  ¿Qué opciones tiene?
# Speaker SPEAKER_01:  Porque entrar en un mundo digital ahora, con 50 años, dos hijos y una hipoteca, no es una opción para Paquita.
# Speaker SPEAKER_01:  Porque tiene otras prioridades y no tiene esas capacidades.
# Speaker SPEAKER_00:  Y ya, a esa edad es difícil aprender, es menos flexible...
# Speaker SPEAKER_01:  Pero ¿cuál es la solución para Paquita entonces?
# Speaker SPEAKER_01:  Paquita es la renta básica.
# Speaker SPEAKER_00:  Renta básica, jubilación temprana, lo que sea.
# Speaker SPEAKER_01:  Mientras que a Francisco, que tiene las capacidades o las condiciones físicas o a lo mejor no tiene
# Speaker SPEAKER_01:  hijos, no tiene otras dedicaciones y puede emplear todo su potencial a una cosa, pues
# Speaker SPEAKER_01:  sí que puede dedicarse a esto. Entonces hay que darle facilidades para que
# Speaker SPEAKER_01:  se dedique a esto, no para que se busque otro trabajo que en un futuro pueda ser...
# Speaker SPEAKER_01:  También lo has reemplazado.
# Speaker SPEAKER_00:  Claro.
# Speaker SPEAKER_00:  Bueno, eso no lo puedes saber, ¿no? Al final siempre pueden reemplazar al final todos los
# Speaker SPEAKER_00:  trabajos.
# Speaker SPEAKER_01:  Sí, pero bueno, hasta lo que conocemos.
# Speaker SPEAKER_00:  Claro, la predicción que tengas tú, pues eso. Un poco relacionado con eso de predecir
# Speaker SPEAKER_00:  un poco las demandas del mercado para abrir ciertas plazas de universidad o cerrar otra.
# Speaker SPEAKER_00:  ¿Eso?
# Speaker SPEAKER_00:  Vale, sí.
# Speaker SPEAKER_01:  Y... bueno, ya está.
# Speaker SPEAKER_00:  Ya está, quería volver al tema de los cuatro grupos. Entonces tenemos los caramelitos,
# Speaker SPEAKER_00:  que serían el grupo muy motivado y muy competente. Tenemos luego un grupo muy competente pero poco motivado
# Speaker SPEAKER_00:  que a eso habría que ver cómo aumentar esa motivación, ¿vale? Y que eso ya se ha visto
# Speaker SPEAKER_00:  que pues por ejemplo para el Sistem se ha aumentado con este incremento de las tecnologías
# Speaker SPEAKER_00:  y viendo que las condiciones laborales son buenas.
# Speaker SPEAKER_01:  La condición es incremento de herramientas que me permiten adquirir esa motivación desde
# Speaker SPEAKER_00:  otras fuentes. Yo creo que también el reemplazo o la automatización de tareas repetitivas también es un aliciente
# Speaker SPEAKER_00:  porque al final por una carrera muy técnica y un conocimiento muy bueno que tú tengas,
# Speaker SPEAKER_00:  todos los trabajos hay tareas repetitivas, que eso es un coñazo, a nadie le gustan.
# Speaker SPEAKER_00:  Y eso es bueno para poder hacer luego las personas un trabajo inteligente y productivo
# Speaker SPEAKER_00:  y no perder horas de tu jornada laboral copiando celdas en un Excel.
# Speaker SPEAKER_01:  Luego tenemos el tercer grupo, que son los muy motivados pero poco competentes.
# Speaker SPEAKER_01:  Entonces como aumentarse esa competencia, mediante programas de formación a lo mejor,
# Speaker SPEAKER_00:  o desarrollo la parte teórica, porque la práctica ya la tienen. Vale, y finalmente con el grupo de poco motivados y poco competentes, ¿qué hacemos?
# Speaker SPEAKER_01:  Pues estos a los cajeros.
# Speaker SPEAKER_01:  A los cajeros y que les sustituyan.
# Speaker SPEAKER_00:  Exacto.
# Speaker SPEAKER_00:  A estos renta básica universal y que no molesten mucho.
# Speaker SPEAKER_00:  Estos son paquita, claro.
# Speaker SPEAKER_00:  Les quitamos el derecho a voto y ya está.
# Speaker SPEAKER_00:  Claro.
# Speaker SPEAKER_01:  Bien. ¿Vale? Vale, eso es mi planteamiento.

# %%
# Initialize an empty list to store the merged result
merged_result = []

# Keep track of the last speaker to detect changes
last_speaker = None
current_text = ""
current_timestamp = None

for chunk in combined_result:
    speaker = chunk['main_speaker']
    text = chunk['text']
    timestamp = chunk['timestamp']

    # If this speaker is the same as the last one, concatenate the text
    if speaker == last_speaker:
        current_text += " " + text  # Add space between concatenated text segments
    else:
        # If a new speaker starts, save the previous speaker's concatenated text
        if last_speaker is not None:
            merged_result.append({
                'speaker': last_speaker,
                'text': current_text,
                'timestamp': current_timestamp
            })
        
        # Start a new text segment for the current speaker
        last_speaker = speaker
        current_text = text
        current_timestamp = timestamp  # Capture timestamp of the first chunk for this speaker

# Append the final speaker's text
if last_speaker is not None:
    merged_result.append({
        'speaker': last_speaker,
        'text': current_text,
        'timestamp': current_timestamp
    })

# Display the merged result
for entry in merged_result:
    print(f"{entry['speaker']}: {entry['text']}")
# Out:
# SPEAKER_01:  Venga. Vale, se plantea la cuestión de por qué hay ciertas carreras, sobre todo las  tecnológicas, las STEM, ahora han cobrado más importancia, dejando a otras en declive  en estos últimos años. Vale. No lo tienes por qué hacer bien, es una conversación. Venga, cuéntamelo.  Vale, bueno, hemos estructurado las carreras en cuatro grupos, o sea, tenemos cuatro grupos  claramente…
# SPEAKER_00:  De estudiantes, no de carreras.
# SPEAKER_01:  Estudiantes o trabajadores. En todas las organizaciones, vamos a decir, tanto universidades como empresas,  diferenciamos cuatro grupos que son los que vienen diferenciados principalmente por la motivación  y por los conocimientos o competencias que tiene cada uno.  Tenemos los primeros que son los que dicen o piensan, bueno, los que tienen las competencias  y les gusta lo que hacen, es decir, se me da bien y me gusta.
# SPEAKER_00:  O sea, tenemos un grupo que sería el empleo perfecto, los que se te hagan bien y además les  gusta estar motivados con el tema, ¿vale? Segundo grupo.
# SPEAKER_01:  Estos son los vocacionales, que son los que define Karl Newport en su libro de no sé qué,  que ahora lo leeré.  Esta es tu primera referencia. Sí. De Karl Newport. en su libro de no sé qué, que ahora lo leeré.
# SPEAKER_00:  Esta es tu primera referencia.
# SPEAKER_01:  Sí.  De Carl Newport.  Sí.  Pues que los define como aquellos que están centrados en su trabajo, por lo tanto aumentan  su productividad.  Son los trabajadores profundos.  Es que tendría que explicar un poco más lo de...  Cariño, tienes cuatro minutos. Ya, pero tengo que explicar un poco más eso.  Que en su estudio se focaliza en la importancia de estar conectado en un mundo con tantos  estímulos y tantos cambios. Eso también lo dice ahí.  Claro, porque si no estás conectado estás en el limbo. Si estás en el limbo, no haces...  ¿Conectado o concentrado?  Conectado es concentrado en lo que haces.  En lo que haces y además te gusta.  Bueno, este es el talento que les interesa a las empresas retener principalmente.  Luego...  Claro, las empresas tienen que trabajar en este grupo para mantener esa motivación  y esos conocimientos.  Luego tenemos el segundo grupo, que es donde más ha impactado el auge de la tecnología  y ha hecho que en este grupo se aumente la motivación por estudiar carreras STEM,  que son los que tienen las competencias adecuadas, pero a lo mejor no están tan convencidos de si les gusta o no  y...
# SPEAKER_00:  o sea que no tienen tanta motivación
# SPEAKER_01:  exacto, no tienen tanta motivación porque  pues porque, por las causas de desmotivación  principales  como pueden ser a lo mejor dificultades, no tienen tanta accesibilidad  a los recursos digitales, como pueden ser las mujeres en este caso, pues cuántas mujeres  hay en una clase de matemáticas?  En una carrera de matemáticas, en comparación a los hombres.
# SPEAKER_00:  En matemáticas es más, es más ingenierías e informática.
# SPEAKER_01:  Pues lo menciono aquí.  ¿Qué se tiene que hacer con esta gente?  Es gente competente, por lo tanto nos interesa en la empresa porque nos pueden aportar.
# SPEAKER_00:  Aquí estás mezclando cosas. Una cosa es el análisis de lo que ya ha pasado, que es  que han aumentado el número de stems, de interés por stems, y eso es porque en los  trabajos de STEM hay mejores condiciones, porque tenemos más acceso a toda información  en aprendizaje individual, que ya es independiente de los profesores, y tenemos una generación  de nativos digitales y de gente que se ha acercado más a la tecnología  a causa del COVID que facilita este aprendizaje con las herramientas digitales. Esto es lo que  ya ha pasado. Ahora sigue habiendo más demanda de STEM que de gente que estudia STEM, de momento, ¿no? El mercado. Las empresas buscan más perfiles de STEM  de los que hay disponibles. Entonces, ¿qué podemos hacer?
# SPEAKER_01:  ¿Por qué hay esta escasez de gente titulada en STEM? ¿Por qué? Si las empresas están  ofreciendo las mejores condiciones en estas empresas.
# SPEAKER_00:  Porque la gente no tiene conocimiento o no elige la carrera en función a su futuro.
# SPEAKER_01:  No, porque la gente no está motivada para estudiar esto, a pesar de que les den estas condiciones.  A pesar de que me vayan a pagar 50.000 euros, no me interesa estudiar tecnología.  No me interesa, a pesar. No me interesa a pesar de que  se me dé bien. Entonces, ¿dónde está el límite? ¿Cuál es mi estímulo principal  para estudiar esto? Esto es lo que me están preguntando. ¿De dónde viene esa motivación?  Pues depende, depende de cada uno. Al final hay que generalizar, es muy difícil.
# SPEAKER_00:  Pero hay que hacerlo para hacer políticas.  No puedes hacer una política para cada persona.
# SPEAKER_01:  ¿Cuáles son las políticas que funcionan mejor?
# SPEAKER_00:  Pues hemos dicho dos.  Hemos dicho adaptar el número de plazas universitarias  a las demandas previstas futuras del mercado.  Es decir, predisco que vamos a necesitar en cinco años  20.000 más STEM.  Pues abrimos 20.000 plazas de STEM, de diferentes carreras, de ingeniería,  de informática, de matemáticas, física, lo que sea.  Viceversa.  Vemos que se está reduciendo la necesidad de gente que hace  turismo o gente, conductores de taxi,  o trabajos a lo mejor más sistemáticos de oficina,  por la otra referencia esta que tenías,  de que se van a reemplazar los trabajos.
# SPEAKER_01:  Inciso.  Pero es que la limitación de estas plazas  crea más desmotivación.  Porque a lo mejor yo pienso que no soy capaz  o que hay mucha mayor gente  que está mejor capacitada que yo  para estudiar esta carrera.  Entonces yo directamente no voy a aplicar.  Si sé que hay 20 plazas...
# SPEAKER_00:  Pero es que va a haber más plazas  porque el mercado demanda más esto.  ¿Lo entiendes? Va a haber muchas más plazas.  O sea, crear empleo. No, empleo no. plazas porque el mercado demanda más esto. ¿Lo entiendes? Va a haber muchas más plazas porque hay mucha más demanda. O sea, crear empleo.  No, empleo no.  Plazas universitarias.  El empleo ya es el que es y eso lo gestiona el mercado.  Ahora tenemos que hacer que el Estado  haga una forma de poner en contacto a las empresas de los universidades  para satisfacer la demanda de empleo  desde cuando la gente elige la carrera, la educación.  ¿Entiendes?  ¿Y por qué no lo hacen?  Esa sería mi pregunta.  Pues porque no les da la gana.  Que no...  Porque no les interesa, ¿eh?  Porque el Estado es una mierda, lo único que quieren es ganar las siguientes elecciones.  No les interesa, no, claro.  Y quieren, de hecho,  quieren población que haya estudiado una carrera de filosofía, que luego no les sirva para nada  y esté muy indignado con el capitalismo en las empresas.  Porque el Estado, pues suele ir en contra de eso, sobre todo en Europa,  siendo un Estado socialista.
# SPEAKER_01:  No, porque a lo mejor no tienen suficiente financiación para...
# SPEAKER_00:  ¿Que no tienen suficiente financiación el Estado?  Literalmente la mitad de lo que pagas va al Estado.
# SPEAKER_01:  No les interesa a lo mejor financiar  la accesibilidad de la gente a recursos tecnológicos.
# SPEAKER_00:  No les interesa, pero bueno, se debería hacer, ¿no?  Y esa sería la solución o una de las soluciones.  Y luego tú antes ahí habías dicho otra.  Que no me acuerdo cuál era.
# SPEAKER_01:  Una solución a la motivación.
# SPEAKER_00:  Sí. Ah, a la gente que reemplazan por máquinas.
# SPEAKER_01:  Por máquinas, exacto.  Pues hay otro estudio.  ¿Dilo?  Sí, es el estudio de McKinsey que dice eso.  Fue escrito en 2017 y decía que antes de la pandemia  se estimaba ya que entre 400 y 800 millones de empleos  iban a ser reemplazados por máquinas.  Esto ya ha pasado. Ya hay muchísimos empleos que ya a ser reemplazados por máquinas. Esto ya ha pasado. O sea, ya  hay muchísimos empleos que ya se han reemplazado.
# SPEAKER_00:  Y va a haber más. Antes eran trabajos más mecánicos, cajero y supermercado y tal.
# SPEAKER_01:  Sí, que también dicen que las tareas repetitivas son altamente susceptibles a la automatización.
# SPEAKER_00:  Pero ahora cada vez más empleos quizás no tan repetitivos se van a ir sustituyendo,  como puede ser un conductor de taxi o de camión, o como puede ser trabajos incluso de oficina.  Esto también crea desmotivación.  Vale.  Sí, pero entonces lo que decías era para esta gente a la que están sustituyendo, tanto  para la gente joven como la gente mayor, ¿no?  Que a lo mejor llevan toda su carrera laboral haciendo este trabajo.
# SPEAKER_01:  Pues sí, a lo mejor una solución sería...
# SPEAKER_00:  Darles opciones, ¿no?  O tenemos la renta básica universal para que puedan tener acceso a estudiar otras cosas.  Eso es de otro estudio, pero bueno, es una de las soluciones.
# SPEAKER_01:  No, una de las soluciones es tener en cuenta, o sea, la solución, la única solución es tener siempre en cuenta las condiciones en las que tienes a tus empleados.  Porque no les va a afectar de la misma manera que a uno le cambies el sueldo o que a uno le des más ventajas que a otro. A cada uno le afecta todo de manera diferente,  en eso estamos de acuerdo. Igual que les afecta diferente a estos cuatro grupos en la implementación  de la tecnología. Pues que las soluciones es siempre tener en cuenta las condiciones de los empleados.
# SPEAKER_00:  ¿Pero qué empleados?  Que le estamos sustituyendo a Paquita la cajera del supermercado.
# SPEAKER_01:  Paquita tiene 50 años y solo sabe  pasar productos por la caja.
# SPEAKER_00:  Entonces las condiciones dan igual, porque la van a despedir y van a poner una robot a hacer eso.  Claro, entonces... ¿Qué hacemos con Paquita?
# SPEAKER_01:  Hay que compensarla teniendo en cuenta qué opciones tiene Paquita.  ¿Qué opciones tiene?  Porque entrar en un mundo digital ahora, con 50 años, dos hijos y una hipoteca, no es una opción para Paquita.  Porque tiene otras prioridades y no tiene esas capacidades.
# SPEAKER_00:  Y ya, a esa edad es difícil aprender, es menos flexible...
# SPEAKER_01:  Pero ¿cuál es la solución para Paquita entonces?  Paquita es la renta básica.
# SPEAKER_00:  Renta básica, jubilación temprana, lo que sea.
# SPEAKER_01:  Mientras que a Francisco, que tiene las capacidades o las condiciones físicas o a lo mejor no tiene  hijos, no tiene otras dedicaciones y puede emplear todo su potencial a una cosa, pues  sí que puede dedicarse a esto. Entonces hay que darle facilidades para que  se dedique a esto, no para que se busque otro trabajo que en un futuro pueda ser...  También lo has reemplazado.
# SPEAKER_00:  Claro.  Bueno, eso no lo puedes saber, ¿no? Al final siempre pueden reemplazar al final todos los  trabajos.
# SPEAKER_01:  Sí, pero bueno, hasta lo que conocemos.
# SPEAKER_00:  Claro, la predicción que tengas tú, pues eso. Un poco relacionado con eso de predecir  un poco las demandas del mercado para abrir ciertas plazas de universidad o cerrar otra.  ¿Eso?  Vale, sí.
# SPEAKER_01:  Y... bueno, ya está.
# SPEAKER_00:  Ya está, quería volver al tema de los cuatro grupos. Entonces tenemos los caramelitos,  que serían el grupo muy motivado y muy competente. Tenemos luego un grupo muy competente pero poco motivado  que a eso habría que ver cómo aumentar esa motivación, ¿vale? Y que eso ya se ha visto  que pues por ejemplo para el Sistem se ha aumentado con este incremento de las tecnologías  y viendo que las condiciones laborales son buenas.
# SPEAKER_01:  La condición es incremento de herramientas que me permiten adquirir esa motivación desde
# SPEAKER_00:  otras fuentes. Yo creo que también el reemplazo o la automatización de tareas repetitivas también es un aliciente  porque al final por una carrera muy técnica y un conocimiento muy bueno que tú tengas,  todos los trabajos hay tareas repetitivas, que eso es un coñazo, a nadie le gustan.  Y eso es bueno para poder hacer luego las personas un trabajo inteligente y productivo  y no perder horas de tu jornada laboral copiando celdas en un Excel.
# SPEAKER_01:  Luego tenemos el tercer grupo, que son los muy motivados pero poco competentes.  Entonces como aumentarse esa competencia, mediante programas de formación a lo mejor,
# SPEAKER_00:  o desarrollo la parte teórica, porque la práctica ya la tienen. Vale, y finalmente con el grupo de poco motivados y poco competentes, ¿qué hacemos?
# SPEAKER_01:  Pues estos a los cajeros.  A los cajeros y que les sustituyan.
# SPEAKER_00:  Exacto.  A estos renta básica universal y que no molesten mucho.  Estos son paquita, claro.  Les quitamos el derecho a voto y ya está.  Claro.
# SPEAKER_01:  Bien. ¿Vale? Vale, eso es mi planteamiento.

# %%
for entry in merged_result:
    # Format the timestamp into start and end time with a clearer structure
    start_time, end_time = entry['timestamp']
    start_time_formatted = f"{int(start_time // 60)}:{int(start_time % 60):02}.{int((start_time % 1) * 100):02}"
    end_time_formatted = f"{int(end_time // 60)}:{int(end_time % 60):02}.{int((end_time % 1) * 100):02}"
    
    # Displaying the speaker, timestamp, and text in a more readable way
    print(f"{entry['speaker']} ({start_time_formatted} - {end_time_formatted}): {entry['text']}")
# Out:
# LIDIA (0:00.00 - 0:08.43):  Venga. Vale, se plantea la cuestión de por qué hay ciertas carreras, sobre todo las  tecnológicas, las STEM, ahora han cobrado más importancia, dejando a otras en declive  en estos últimos años. Vale. No lo tienes por qué hacer bien, es una conversación. Venga, cuéntamelo.  Vale, bueno, hemos estructurado las carreras en cuatro grupos, o sea, tenemos cuatro grupos  claramente…
# LUIS (0:37.11 - 0:39.11):  De estudiantes, no de carreras.
# LIDIA (0:39.11 - 0:46.00):  Estudiantes o trabajadores. En todas las organizaciones, vamos a decir, tanto universidades como empresas,  diferenciamos cuatro grupos que son los que vienen diferenciados principalmente por la motivación  y por los conocimientos o competencias que tiene cada uno.  Tenemos los primeros que son los que dicen o piensan, bueno, los que tienen las competencias  y les gusta lo que hacen, es decir, se me da bien y me gusta.
# LUIS (1:06.51 - 1:12.15):  O sea, tenemos un grupo que sería el empleo perfecto, los que se te hagan bien y además les  gusta estar motivados con el tema, ¿vale? Segundo grupo.
# LIDIA (1:14.95 - 1:24.04):  Estos son los vocacionales, que son los que define Karl Newport en su libro de no sé qué,  que ahora lo leeré.  Esta es tu primera referencia. Sí. De Karl Newport. en su libro de no sé qué, que ahora lo leeré.
# LUIS (1:25.00 - 1:27.00):  Esta es tu primera referencia.
# LIDIA (1:27.00 - 1:28.00):  Sí.  De Carl Newport.  Sí.  Pues que los define como aquellos que están centrados en su trabajo, por lo tanto aumentan  su productividad.  Son los trabajadores profundos.  Es que tendría que explicar un poco más lo de...  Cariño, tienes cuatro minutos. Ya, pero tengo que explicar un poco más eso.  Que en su estudio se focaliza en la importancia de estar conectado en un mundo con tantos  estímulos y tantos cambios. Eso también lo dice ahí.  Claro, porque si no estás conectado estás en el limbo. Si estás en el limbo, no haces...  ¿Conectado o concentrado?  Conectado es concentrado en lo que haces.  En lo que haces y además te gusta.  Bueno, este es el talento que les interesa a las empresas retener principalmente.  Luego...  Claro, las empresas tienen que trabajar en este grupo para mantener esa motivación  y esos conocimientos.  Luego tenemos el segundo grupo, que es donde más ha impactado el auge de la tecnología  y ha hecho que en este grupo se aumente la motivación por estudiar carreras STEM,  que son los que tienen las competencias adecuadas, pero a lo mejor no están tan convencidos de si les gusta o no  y...
# LUIS (2:50.56 - 2:54.15):  o sea que no tienen tanta motivación
# LIDIA (2:54.15 - 2:57.19):  exacto, no tienen tanta motivación porque  pues porque, por las causas de desmotivación  principales  como pueden ser a lo mejor dificultades, no tienen tanta accesibilidad  a los recursos digitales, como pueden ser las mujeres en este caso, pues cuántas mujeres  hay en una clase de matemáticas?  En una carrera de matemáticas, en comparación a los hombres.
# LUIS (3:29.00 - 3:33.00):  En matemáticas es más, es más ingenierías e informática.
# LIDIA (3:33.00 - 3:36.00):  Pues lo menciono aquí.  ¿Qué se tiene que hacer con esta gente?  Es gente competente, por lo tanto nos interesa en la empresa porque nos pueden aportar.
# LUIS (3:43.00 - 3:48.15):  Aquí estás mezclando cosas. Una cosa es el análisis de lo que ya ha pasado, que es  que han aumentado el número de stems, de interés por stems, y eso es porque en los  trabajos de STEM hay mejores condiciones, porque tenemos más acceso a toda información  en aprendizaje individual, que ya es independiente de los profesores, y tenemos una generación  de nativos digitales y de gente que se ha acercado más a la tecnología  a causa del COVID que facilita este aprendizaje con las herramientas digitales. Esto es lo que  ya ha pasado. Ahora sigue habiendo más demanda de STEM que de gente que estudia STEM, de momento, ¿no? El mercado. Las empresas buscan más perfiles de STEM  de los que hay disponibles. Entonces, ¿qué podemos hacer?
# LIDIA (4:33.12 - 4:42.19):  ¿Por qué hay esta escasez de gente titulada en STEM? ¿Por qué? Si las empresas están  ofreciendo las mejores condiciones en estas empresas.
# LUIS (4:46.39 - 4:52.39):  Porque la gente no tiene conocimiento o no elige la carrera en función a su futuro.
# LIDIA (4:52.39 - 4:58.39):  No, porque la gente no está motivada para estudiar esto, a pesar de que les den estas condiciones.  A pesar de que me vayan a pagar 50.000 euros, no me interesa estudiar tecnología.  No me interesa, a pesar. No me interesa a pesar de que  se me dé bien. Entonces, ¿dónde está el límite? ¿Cuál es mi estímulo principal  para estudiar esto? Esto es lo que me están preguntando. ¿De dónde viene esa motivación?  Pues depende, depende de cada uno. Al final hay que generalizar, es muy difícil.
# LUIS (5:24.30 - 5:26.00):  Pero hay que hacerlo para hacer políticas.  No puedes hacer una política para cada persona.
# LIDIA (5:28.00 - 5:30.00):  ¿Cuáles son las políticas que funcionan mejor?
# LUIS (5:30.00 - 5:32.00):  Pues hemos dicho dos.  Hemos dicho adaptar el número de plazas universitarias  a las demandas previstas futuras del mercado.  Es decir, predisco que vamos a necesitar en cinco años  20.000 más STEM.  Pues abrimos 20.000 plazas de STEM, de diferentes carreras, de ingeniería,  de informática, de matemáticas, física, lo que sea.  Viceversa.  Vemos que se está reduciendo la necesidad de gente que hace  turismo o gente, conductores de taxi,  o trabajos a lo mejor más sistemáticos de oficina,  por la otra referencia esta que tenías,  de que se van a reemplazar los trabajos.
# LIDIA (6:02.95 - 6:03.80):  Inciso.  Pero es que la limitación de estas plazas  crea más desmotivación.  Porque a lo mejor yo pienso que no soy capaz  o que hay mucha mayor gente  que está mejor capacitada que yo  para estudiar esta carrera.  Entonces yo directamente no voy a aplicar.  Si sé que hay 20 plazas...
# LUIS (6:20.00 - 6:21.00):  Pero es que va a haber más plazas  porque el mercado demanda más esto.  ¿Lo entiendes? Va a haber muchas más plazas.  O sea, crear empleo. No, empleo no. plazas porque el mercado demanda más esto. ¿Lo entiendes? Va a haber muchas más plazas porque hay mucha más demanda. O sea, crear empleo.  No, empleo no.  Plazas universitarias.  El empleo ya es el que es y eso lo gestiona el mercado.  Ahora tenemos que hacer que el Estado  haga una forma de poner en contacto a las empresas de los universidades  para satisfacer la demanda de empleo  desde cuando la gente elige la carrera, la educación.  ¿Entiendes?  ¿Y por qué no lo hacen?  Esa sería mi pregunta.  Pues porque no les da la gana.  Que no...  Porque no les interesa, ¿eh?  Porque el Estado es una mierda, lo único que quieren es ganar las siguientes elecciones.  No les interesa, no, claro.  Y quieren, de hecho,  quieren población que haya estudiado una carrera de filosofía, que luego no les sirva para nada  y esté muy indignado con el capitalismo en las empresas.  Porque el Estado, pues suele ir en contra de eso, sobre todo en Europa,  siendo un Estado socialista.
# LIDIA (7:09.19 - 7:12.72):  No, porque a lo mejor no tienen suficiente financiación para...
# LUIS (7:12.80 - 7:14.39):  ¿Que no tienen suficiente financiación el Estado?  Literalmente la mitad de lo que pagas va al Estado.
# LIDIA (7:17.51 - 7:20.72):  No les interesa a lo mejor financiar  la accesibilidad de la gente a recursos tecnológicos.
# LUIS (7:24.51 - 7:26.80):  No les interesa, pero bueno, se debería hacer, ¿no?  Y esa sería la solución o una de las soluciones.  Y luego tú antes ahí habías dicho otra.  Que no me acuerdo cuál era.
# LIDIA (7:34.10 - 7:38.80):  Una solución a la motivación.
# LUIS (7:38.80 - 7:44.00):  Sí. Ah, a la gente que reemplazan por máquinas.
# LIDIA (7:44.00 - 7:44.80):  Por máquinas, exacto.  Pues hay otro estudio.  ¿Dilo?  Sí, es el estudio de McKinsey que dice eso.  Fue escrito en 2017 y decía que antes de la pandemia  se estimaba ya que entre 400 y 800 millones de empleos  iban a ser reemplazados por máquinas.  Esto ya ha pasado. Ya hay muchísimos empleos que ya a ser reemplazados por máquinas. Esto ya ha pasado. O sea, ya  hay muchísimos empleos que ya se han reemplazado.
# LUIS (8:07.56 - 8:10.95):  Y va a haber más. Antes eran trabajos más mecánicos, cajero y supermercado y tal.
# LIDIA (8:10.95 - 8:15.75):  Sí, que también dicen que las tareas repetitivas son altamente susceptibles a la automatización.
# LUIS (8:15.75 - 8:19.68):  Pero ahora cada vez más empleos quizás no tan repetitivos se van a ir sustituyendo,  como puede ser un conductor de taxi o de camión, o como puede ser trabajos incluso de oficina.  Esto también crea desmotivación.  Vale.  Sí, pero entonces lo que decías era para esta gente a la que están sustituyendo, tanto  para la gente joven como la gente mayor, ¿no?  Que a lo mejor llevan toda su carrera laboral haciendo este trabajo.
# LIDIA (8:38.72 - 8:39.72):  Pues sí, a lo mejor una solución sería...
# LUIS (8:39.72 - 8:40.72):  Darles opciones, ¿no?  O tenemos la renta básica universal para que puedan tener acceso a estudiar otras cosas.  Eso es de otro estudio, pero bueno, es una de las soluciones.
# LIDIA (8:49.00 - 9:00.00):  No, una de las soluciones es tener en cuenta, o sea, la solución, la única solución es tener siempre en cuenta las condiciones en las que tienes a tus empleados.  Porque no les va a afectar de la misma manera que a uno le cambies el sueldo o que a uno le des más ventajas que a otro. A cada uno le afecta todo de manera diferente,  en eso estamos de acuerdo. Igual que les afecta diferente a estos cuatro grupos en la implementación  de la tecnología. Pues que las soluciones es siempre tener en cuenta las condiciones de los empleados.
# LUIS (9:30.55 - 9:31.29):  ¿Pero qué empleados?  Que le estamos sustituyendo a Paquita la cajera del supermercado.
# LIDIA (9:34.34 - 9:37.20):  Paquita tiene 50 años y solo sabe  pasar productos por la caja.
# LUIS (9:39.94 - 9:43.98):  Entonces las condiciones dan igual, porque la van a despedir y van a poner una robot a hacer eso.  Claro, entonces... ¿Qué hacemos con Paquita?
# LIDIA (9:46.00 - 9:51.00):  Hay que compensarla teniendo en cuenta qué opciones tiene Paquita.  ¿Qué opciones tiene?  Porque entrar en un mundo digital ahora, con 50 años, dos hijos y una hipoteca, no es una opción para Paquita.  Porque tiene otras prioridades y no tiene esas capacidades.
# LUIS (10:05.91 - 10:09.79):  Y ya, a esa edad es difícil aprender, es menos flexible...
# LIDIA (10:09.79 - 10:12.60):  Pero ¿cuál es la solución para Paquita entonces?  Paquita es la renta básica.
# LUIS (10:15.55 - 10:18.55):  Renta básica, jubilación temprana, lo que sea.
# LIDIA (10:18.55 - 10:30.13):  Mientras que a Francisco, que tiene las capacidades o las condiciones físicas o a lo mejor no tiene  hijos, no tiene otras dedicaciones y puede emplear todo su potencial a una cosa, pues  sí que puede dedicarse a esto. Entonces hay que darle facilidades para que  se dedique a esto, no para que se busque otro trabajo que en un futuro pueda ser...  También lo has reemplazado.
# LUIS (10:52.55 - 10:53.55):  Claro.  Bueno, eso no lo puedes saber, ¿no? Al final siempre pueden reemplazar al final todos los  trabajos.
# LIDIA (10:57.51 - 11:00.91):  Sí, pero bueno, hasta lo que conocemos.
# LUIS (11:00.91 - 11:05.00):  Claro, la predicción que tengas tú, pues eso. Un poco relacionado con eso de predecir  un poco las demandas del mercado para abrir ciertas plazas de universidad o cerrar otra.  ¿Eso?  Vale, sí.
# LIDIA (11:11.00 - 11:14.00):  Y... bueno, ya está.
# LUIS (11:14.00 - 11:19.00):  Ya está, quería volver al tema de los cuatro grupos. Entonces tenemos los caramelitos,  que serían el grupo muy motivado y muy competente. Tenemos luego un grupo muy competente pero poco motivado  que a eso habría que ver cómo aumentar esa motivación, ¿vale? Y que eso ya se ha visto  que pues por ejemplo para el Sistem se ha aumentado con este incremento de las tecnologías  y viendo que las condiciones laborales son buenas.
# LIDIA (11:38.27 - 11:43.36):  La condición es incremento de herramientas que me permiten adquirir esa motivación desde
# LUIS (11:43.36 - 11:51.03):  otras fuentes. Yo creo que también el reemplazo o la automatización de tareas repetitivas también es un aliciente  porque al final por una carrera muy técnica y un conocimiento muy bueno que tú tengas,  todos los trabajos hay tareas repetitivas, que eso es un coñazo, a nadie le gustan.  Y eso es bueno para poder hacer luego las personas un trabajo inteligente y productivo  y no perder horas de tu jornada laboral copiando celdas en un Excel.
# LIDIA (12:16.55 - 12:16.84):  Luego tenemos el tercer grupo, que son los muy motivados pero poco competentes.  Entonces como aumentarse esa competencia, mediante programas de formación a lo mejor,
# LUIS (12:29.00 - 12:33.00):  o desarrollo la parte teórica, porque la práctica ya la tienen. Vale, y finalmente con el grupo de poco motivados y poco competentes, ¿qué hacemos?
# LIDIA (12:33.00 - 12:35.00):  Pues estos a los cajeros.  A los cajeros y que les sustituyan.
# LUIS (12:37.00 - 12:38.00):  Exacto.  A estos renta básica universal y que no molesten mucho.  Estos son paquita, claro.  Les quitamos el derecho a voto y ya está.  Claro.
# LIDIA (12:44.00 - 12:48.03):  Bien. ¿Vale? Vale, eso es mi planteamiento.

# %% [markdown]
# ## Choose speakers

# %%
# Select the speaker names (if unknow, speaker_names = None)
speaker_names = ["LUIS", "LIDIA"]

# %%
def replace_speaker_names(merged_result, speaker_names=None):

    if speaker_names == None:
        return merged_result
    # Create a dictionary to map SPEAKER_XX to provided names
    speaker_map = {f"SPEAKER_{str(i).zfill(2)}": name for i, name in enumerate(speaker_names)}
    
    # Replace speaker names in merged_result
    for entry in merged_result:
        if entry['speaker'] in speaker_map:
            entry['speaker'] = speaker_map[entry['speaker']]
    
    return merged_result

# Example usage:
# Assuming merged_result is the result from the code you shared

# Call the function
updated_result = replace_speaker_names(merged_result, speaker_names)

# Display the updated merged result
for entry in updated_result:
    print(f"{entry['speaker']}: {entry['text']}")
# Out:
# LIDIA:  Venga. Vale, se plantea la cuestión de por qué hay ciertas carreras, sobre todo las  tecnológicas, las STEM, ahora han cobrado más importancia, dejando a otras en declive  en estos últimos años. Vale. No lo tienes por qué hacer bien, es una conversación. Venga, cuéntamelo.  Vale, bueno, hemos estructurado las carreras en cuatro grupos, o sea, tenemos cuatro grupos  claramente…
# LUIS:  De estudiantes, no de carreras.
# LIDIA:  Estudiantes o trabajadores. En todas las organizaciones, vamos a decir, tanto universidades como empresas,  diferenciamos cuatro grupos que son los que vienen diferenciados principalmente por la motivación  y por los conocimientos o competencias que tiene cada uno.  Tenemos los primeros que son los que dicen o piensan, bueno, los que tienen las competencias  y les gusta lo que hacen, es decir, se me da bien y me gusta.
# LUIS:  O sea, tenemos un grupo que sería el empleo perfecto, los que se te hagan bien y además les  gusta estar motivados con el tema, ¿vale? Segundo grupo.
# LIDIA:  Estos son los vocacionales, que son los que define Karl Newport en su libro de no sé qué,  que ahora lo leeré.  Esta es tu primera referencia. Sí. De Karl Newport. en su libro de no sé qué, que ahora lo leeré.
# LUIS:  Esta es tu primera referencia.
# LIDIA:  Sí.  De Carl Newport.  Sí.  Pues que los define como aquellos que están centrados en su trabajo, por lo tanto aumentan  su productividad.  Son los trabajadores profundos.  Es que tendría que explicar un poco más lo de...  Cariño, tienes cuatro minutos. Ya, pero tengo que explicar un poco más eso.  Que en su estudio se focaliza en la importancia de estar conectado en un mundo con tantos  estímulos y tantos cambios. Eso también lo dice ahí.  Claro, porque si no estás conectado estás en el limbo. Si estás en el limbo, no haces...  ¿Conectado o concentrado?  Conectado es concentrado en lo que haces.  En lo que haces y además te gusta.  Bueno, este es el talento que les interesa a las empresas retener principalmente.  Luego...  Claro, las empresas tienen que trabajar en este grupo para mantener esa motivación  y esos conocimientos.  Luego tenemos el segundo grupo, que es donde más ha impactado el auge de la tecnología  y ha hecho que en este grupo se aumente la motivación por estudiar carreras STEM,  que son los que tienen las competencias adecuadas, pero a lo mejor no están tan convencidos de si les gusta o no  y...
# LUIS:  o sea que no tienen tanta motivación
# LIDIA:  exacto, no tienen tanta motivación porque  pues porque, por las causas de desmotivación  principales  como pueden ser a lo mejor dificultades, no tienen tanta accesibilidad  a los recursos digitales, como pueden ser las mujeres en este caso, pues cuántas mujeres  hay en una clase de matemáticas?  En una carrera de matemáticas, en comparación a los hombres.
# LUIS:  En matemáticas es más, es más ingenierías e informática.
# LIDIA:  Pues lo menciono aquí.  ¿Qué se tiene que hacer con esta gente?  Es gente competente, por lo tanto nos interesa en la empresa porque nos pueden aportar.
# LUIS:  Aquí estás mezclando cosas. Una cosa es el análisis de lo que ya ha pasado, que es  que han aumentado el número de stems, de interés por stems, y eso es porque en los  trabajos de STEM hay mejores condiciones, porque tenemos más acceso a toda información  en aprendizaje individual, que ya es independiente de los profesores, y tenemos una generación  de nativos digitales y de gente que se ha acercado más a la tecnología  a causa del COVID que facilita este aprendizaje con las herramientas digitales. Esto es lo que  ya ha pasado. Ahora sigue habiendo más demanda de STEM que de gente que estudia STEM, de momento, ¿no? El mercado. Las empresas buscan más perfiles de STEM  de los que hay disponibles. Entonces, ¿qué podemos hacer?
# LIDIA:  ¿Por qué hay esta escasez de gente titulada en STEM? ¿Por qué? Si las empresas están  ofreciendo las mejores condiciones en estas empresas.
# LUIS:  Porque la gente no tiene conocimiento o no elige la carrera en función a su futuro.
# LIDIA:  No, porque la gente no está motivada para estudiar esto, a pesar de que les den estas condiciones.  A pesar de que me vayan a pagar 50.000 euros, no me interesa estudiar tecnología.  No me interesa, a pesar. No me interesa a pesar de que  se me dé bien. Entonces, ¿dónde está el límite? ¿Cuál es mi estímulo principal  para estudiar esto? Esto es lo que me están preguntando. ¿De dónde viene esa motivación?  Pues depende, depende de cada uno. Al final hay que generalizar, es muy difícil.
# LUIS:  Pero hay que hacerlo para hacer políticas.  No puedes hacer una política para cada persona.
# LIDIA:  ¿Cuáles son las políticas que funcionan mejor?
# LUIS:  Pues hemos dicho dos.  Hemos dicho adaptar el número de plazas universitarias  a las demandas previstas futuras del mercado.  Es decir, predisco que vamos a necesitar en cinco años  20.000 más STEM.  Pues abrimos 20.000 plazas de STEM, de diferentes carreras, de ingeniería,  de informática, de matemáticas, física, lo que sea.  Viceversa.  Vemos que se está reduciendo la necesidad de gente que hace  turismo o gente, conductores de taxi,  o trabajos a lo mejor más sistemáticos de oficina,  por la otra referencia esta que tenías,  de que se van a reemplazar los trabajos.
# LIDIA:  Inciso.  Pero es que la limitación de estas plazas  crea más desmotivación.  Porque a lo mejor yo pienso que no soy capaz  o que hay mucha mayor gente  que está mejor capacitada que yo  para estudiar esta carrera.  Entonces yo directamente no voy a aplicar.  Si sé que hay 20 plazas...
# LUIS:  Pero es que va a haber más plazas  porque el mercado demanda más esto.  ¿Lo entiendes? Va a haber muchas más plazas.  O sea, crear empleo. No, empleo no. plazas porque el mercado demanda más esto. ¿Lo entiendes? Va a haber muchas más plazas porque hay mucha más demanda. O sea, crear empleo.  No, empleo no.  Plazas universitarias.  El empleo ya es el que es y eso lo gestiona el mercado.  Ahora tenemos que hacer que el Estado  haga una forma de poner en contacto a las empresas de los universidades  para satisfacer la demanda de empleo  desde cuando la gente elige la carrera, la educación.  ¿Entiendes?  ¿Y por qué no lo hacen?  Esa sería mi pregunta.  Pues porque no les da la gana.  Que no...  Porque no les interesa, ¿eh?  Porque el Estado es una mierda, lo único que quieren es ganar las siguientes elecciones.  No les interesa, no, claro.  Y quieren, de hecho,  quieren población que haya estudiado una carrera de filosofía, que luego no les sirva para nada  y esté muy indignado con el capitalismo en las empresas.  Porque el Estado, pues suele ir en contra de eso, sobre todo en Europa,  siendo un Estado socialista.
# LIDIA:  No, porque a lo mejor no tienen suficiente financiación para...
# LUIS:  ¿Que no tienen suficiente financiación el Estado?  Literalmente la mitad de lo que pagas va al Estado.
# LIDIA:  No les interesa a lo mejor financiar  la accesibilidad de la gente a recursos tecnológicos.
# LUIS:  No les interesa, pero bueno, se debería hacer, ¿no?  Y esa sería la solución o una de las soluciones.  Y luego tú antes ahí habías dicho otra.  Que no me acuerdo cuál era.
# LIDIA:  Una solución a la motivación.
# LUIS:  Sí. Ah, a la gente que reemplazan por máquinas.
# LIDIA:  Por máquinas, exacto.  Pues hay otro estudio.  ¿Dilo?  Sí, es el estudio de McKinsey que dice eso.  Fue escrito en 2017 y decía que antes de la pandemia  se estimaba ya que entre 400 y 800 millones de empleos  iban a ser reemplazados por máquinas.  Esto ya ha pasado. Ya hay muchísimos empleos que ya a ser reemplazados por máquinas. Esto ya ha pasado. O sea, ya  hay muchísimos empleos que ya se han reemplazado.
# LUIS:  Y va a haber más. Antes eran trabajos más mecánicos, cajero y supermercado y tal.
# LIDIA:  Sí, que también dicen que las tareas repetitivas son altamente susceptibles a la automatización.
# LUIS:  Pero ahora cada vez más empleos quizás no tan repetitivos se van a ir sustituyendo,  como puede ser un conductor de taxi o de camión, o como puede ser trabajos incluso de oficina.  Esto también crea desmotivación.  Vale.  Sí, pero entonces lo que decías era para esta gente a la que están sustituyendo, tanto  para la gente joven como la gente mayor, ¿no?  Que a lo mejor llevan toda su carrera laboral haciendo este trabajo.
# LIDIA:  Pues sí, a lo mejor una solución sería...
# LUIS:  Darles opciones, ¿no?  O tenemos la renta básica universal para que puedan tener acceso a estudiar otras cosas.  Eso es de otro estudio, pero bueno, es una de las soluciones.
# LIDIA:  No, una de las soluciones es tener en cuenta, o sea, la solución, la única solución es tener siempre en cuenta las condiciones en las que tienes a tus empleados.  Porque no les va a afectar de la misma manera que a uno le cambies el sueldo o que a uno le des más ventajas que a otro. A cada uno le afecta todo de manera diferente,  en eso estamos de acuerdo. Igual que les afecta diferente a estos cuatro grupos en la implementación  de la tecnología. Pues que las soluciones es siempre tener en cuenta las condiciones de los empleados.
# LUIS:  ¿Pero qué empleados?  Que le estamos sustituyendo a Paquita la cajera del supermercado.
# LIDIA:  Paquita tiene 50 años y solo sabe  pasar productos por la caja.
# LUIS:  Entonces las condiciones dan igual, porque la van a despedir y van a poner una robot a hacer eso.  Claro, entonces... ¿Qué hacemos con Paquita?
# LIDIA:  Hay que compensarla teniendo en cuenta qué opciones tiene Paquita.  ¿Qué opciones tiene?  Porque entrar en un mundo digital ahora, con 50 años, dos hijos y una hipoteca, no es una opción para Paquita.  Porque tiene otras prioridades y no tiene esas capacidades.
# LUIS:  Y ya, a esa edad es difícil aprender, es menos flexible...
# LIDIA:  Pero ¿cuál es la solución para Paquita entonces?  Paquita es la renta básica.
# LUIS:  Renta básica, jubilación temprana, lo que sea.
# LIDIA:  Mientras que a Francisco, que tiene las capacidades o las condiciones físicas o a lo mejor no tiene  hijos, no tiene otras dedicaciones y puede emplear todo su potencial a una cosa, pues  sí que puede dedicarse a esto. Entonces hay que darle facilidades para que  se dedique a esto, no para que se busque otro trabajo que en un futuro pueda ser...  También lo has reemplazado.
# LUIS:  Claro.  Bueno, eso no lo puedes saber, ¿no? Al final siempre pueden reemplazar al final todos los  trabajos.
# LIDIA:  Sí, pero bueno, hasta lo que conocemos.
# LUIS:  Claro, la predicción que tengas tú, pues eso. Un poco relacionado con eso de predecir  un poco las demandas del mercado para abrir ciertas plazas de universidad o cerrar otra.  ¿Eso?  Vale, sí.
# LIDIA:  Y... bueno, ya está.
# LUIS:  Ya está, quería volver al tema de los cuatro grupos. Entonces tenemos los caramelitos,  que serían el grupo muy motivado y muy competente. Tenemos luego un grupo muy competente pero poco motivado  que a eso habría que ver cómo aumentar esa motivación, ¿vale? Y que eso ya se ha visto  que pues por ejemplo para el Sistem se ha aumentado con este incremento de las tecnologías  y viendo que las condiciones laborales son buenas.
# LIDIA:  La condición es incremento de herramientas que me permiten adquirir esa motivación desde
# LUIS:  otras fuentes. Yo creo que también el reemplazo o la automatización de tareas repetitivas también es un aliciente  porque al final por una carrera muy técnica y un conocimiento muy bueno que tú tengas,  todos los trabajos hay tareas repetitivas, que eso es un coñazo, a nadie le gustan.  Y eso es bueno para poder hacer luego las personas un trabajo inteligente y productivo  y no perder horas de tu jornada laboral copiando celdas en un Excel.
# LIDIA:  Luego tenemos el tercer grupo, que son los muy motivados pero poco competentes.  Entonces como aumentarse esa competencia, mediante programas de formación a lo mejor,
# LUIS:  o desarrollo la parte teórica, porque la práctica ya la tienen. Vale, y finalmente con el grupo de poco motivados y poco competentes, ¿qué hacemos?
# LIDIA:  Pues estos a los cajeros.  A los cajeros y que les sustituyan.
# LUIS:  Exacto.  A estos renta básica universal y que no molesten mucho.  Estos son paquita, claro.  Les quitamos el derecho a voto y ya está.  Claro.
# LIDIA:  Bien. ¿Vale? Vale, eso es mi planteamiento.

# %%
# Specify the file path
file_path = f"/mnt/c/Users/luisg/Desktop/STAR/STAR/transcriptions_diarized/{filename}.txt"

# Write the merged result to the file
with open(file_path, "w", encoding="utf-8") as file:
    for entry in merged_result:
        file.write(f"{entry['speaker']}: {entry['text']}\n")
